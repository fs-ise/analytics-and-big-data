# %% [markdown]
# # Exercise 6: Machine learning I
#
# Implement a machine learning model in Python, including feature
# engineering, train–test splitting, model training, cross-validation, and
# evaluation.
#
# > **Note**
# >
# > This should be “as simple as possible”
#
# https://github.com/justmarkham/scikit-learn-videos
#
# # Python
#
# ## Implementation in Python with scikit-learn (20 min)
#
# Walk through a simple, reproducible pipeline:
#
# 1.  Load dataset (toy dataset or small real-world example)
# 2.  Train–test split
# 3.  Preprocessing pipeline (e.g., StandardScaler + model)
# 4.  Fit logistic regression vs. one non-linear model (e.g., decision
#     tree or SVM)
# 5.  Compare performance metrics
# 6.  Show how to inspect confusion matrix & classification report
#
# Highlight: - Consistent API (`fit`, `predict`, `score`) - Use of
# `Pipeline` - Keeping code **structured and reproducible**
#
# ## Exam prep
#
# TODO : include specific questions/tasks that could be included in the
# exam.
#
# > **Session 6 survey**
# >
# > Before you wrap up, please complete the Session 6 survey here:
# > <a href="https://forms.gle/AFmpWcopjMtGfNif6"
# > target="_blank">https://forms.gle/AFmpWcopjMtGfNif6</a>. Thank you 🙏
