# %% [markdown]
# # Exercise 7: Machine learning 2
#
# - Implement and evaluate decision trees, and neural networks for a
#   business prediction task.
# - Compare models with respect to accuracy, interpretability, and
#   practical implications.
# - Recommend a suitable model for deployment.
#
# NOTE: see `Data Analytics with Python.pdf`
#
# > **Session 7 survey**
# >
# > Before you wrap up, please complete the Session 7 survey here:
# > <a href="?meta:surveys.session_07.url"
# > target="_blank"><strong>?meta:surveys.session_07.url</strong></a>.
# > Thank you 🙏
