# %% [markdown]
# # Exercise 10: Governance of data analytics
#
# - Analyze how data analytics creates strategic value within a given
#   organizational context.
# - Identify ethical and legal risks in analytics initiatives and propose
#   mitigation strategies.
#
# > **Note**
# >
# > TODO; this could be based on a case study
#
# ## Exam prep
#
# TODO : include specific questions/tasks that could be included in the
# exam.
#
# > **Session 10 survey**
# >
# > Before you wrap up, please complete the Session 10 survey here:
# > <a href="https://forms.gle/Rhr4C47jsAZJyumN6"
# > target="_blank">https://forms.gle/Rhr4C47jsAZJyumN6</a>. Thank you 🙏
