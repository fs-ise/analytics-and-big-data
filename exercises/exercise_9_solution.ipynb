# %% [markdown]
# # Exercise 9: Big data II
#
# Acquire and preprocess large-scale or unstructured data using APIs and
# appropriate tools in Python. Apply large language models or other
# scalable methods to extract, classify, or summarize unstructured data.
#
# > **Note**
# >
# > TODO
# >
# > TBD: API Keys?!
#
# ## Exam prep
#
# TODO : include specific questions/tasks that could be included in the
# exam.
#
# > **Session 9 survey**
# >
# > Before you wrap up, please complete the Session 9 survey here:
# > <a href="https://forms.gle/1vsCsqc3SzWfSX1f6"
# > target="_blank">https://forms.gle/1vsCsqc3SzWfSX1f6</a>. Thank you 🙏
