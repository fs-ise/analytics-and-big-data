# %% [markdown]
# # Exercise 9: Big data II
#
# TODO
#
# ## Part 1: by-hand calculation:
#
# https://www.ismll.uni-hildesheim.de/lehre/ml-19w/exercises/tutorial07.pdf
#
# ## Part 2: interactive playground
#
# insight from
# https://developers.google.com/machine-learning/crash-course/neural-networks/interactive-exercises
# -\> even if all inputs are 0, the output can be non-zero. (due to
# biases)
#
# Generally: https://playground.tensorflow.org/ -\> check different
# datasets!
#
# ## Part 3: Code reading and best practices in modeling
#
# - sklearn vs pytorch
# - examples with architecture choices/understanding
#
# ## Exam prep
#
# TODO : include specific questions/tasks that could be included in the
# exam.
#
# > **Session 9 survey**
# >
# > Before you wrap up, please complete the Session 9 survey here:
# > <a href="https://forms.gle/1vsCsqc3SzWfSX1f6"
# > target="_blank">https://forms.gle/1vsCsqc3SzWfSX1f6</a>. Thank you 🙏
